# %%
import pandas as pd

data=pd.read_csv('Avon_Data_Clean.csv')

# %%
avon=pd.DataFrame(data)
avon.head()
# Out:
#   cv__Campaign__r.Name  Year      City Walk_Participation Walk_Status  \
# 0        2009 New York  2009  New York             Walker      Active
# 1          2010 Boston  2010    Boston               Crew      Active
# 2          2010 Boston  2010    Boston               Crew      Active
# 3          2010 Boston  2010    Boston               Crew      Active
# 4          2010 Boston  2010    Boston               Crew      Active
#
#   Classification  FUL_CHECKED cv__Registration_Date__c  Withdrew  Active  \
# 0     New Direct            0           2/18/2010 0:00         0       1
# 1           Crew            1            1/4/2010 0:00         0       1
# 2           Crew            1           2/12/2010 0:00         0       1
# 3           Crew            1            1/3/2010 0:00         0       1
# 4           Crew            1            1/2/2010 0:00         0       1
#
#           ...           AF_PROMO__c  AF_REG_WAY_OF_ENTRY__c AF_REG_SOURCE__c  \
# ...

# %%
avon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165059 entries, 0 to 165058
# Data columns (total 22 columns):
# cv__Campaign__r.Name         165059 non-null object
# Year                         165059 non-null int64
# City                         165059 non-null object
# Walk_Participation           165059 non-null object
# Walk_Status                  165059 non-null object
# Classification               165059 non-null object
# FUL_CHECKED                  165059 non-null int64
# cv__Registration_Date__c     165059 non-null object
# Withdrew                     165059 non-null int64
# Active                       165059 non-null int64
# Registration_Days_Out        165059 non-null int64
# Opportunity_Amount           163496 non-null float64
# AF_PROMO__c                  85277 non-null object
# AF_REG_WAY_OF_ENTRY__c       164666 non-null object
# AF_REG_SOURCE__c             163936 non-null object
# AF_REG_SOURCE_DETAIL__c      62005 non-null object
# ...

# %%
avon.describe()
# Out:
#                 Year    FUL_CHECKED       Withdrew         Active  \
# count  165059.000000  165059.000000  165059.000000  165059.000000
# mean     2013.061336       0.651088       0.115898       0.884084
# std         2.066444       0.476627       0.320103       0.320125
# min      2009.000000       0.000000       0.000000       0.000000
# 25%      2011.000000       0.000000       0.000000       1.000000
# 50%      2013.000000       1.000000       0.000000       1.000000
# 75%      2015.000000       1.000000       0.000000       1.000000
# max      2017.000000       1.000000       1.000000       1.000000
#
#        Registration_Days_Out  Opportunity_Amount  Age_During_Event__c  \
# count          165059.000000       163496.000000        161687.000000
# mean              191.254230           46.363324            42.372572
# std               111.589557           14.349029            12.439195
# min             -1056.000000            0.000000           -96.000000
# ...

# %%
avon.shape
# Out:
# (165059, 22)

# %%
avon.iloc[0]
# Out:
# cv__Campaign__r.Name          2009 New York
# Year                                   2009
# City                               New York
# Walk_Participation                   Walker
# Walk_Status                          Active
# Classification                   New Direct
# FUL_CHECKED                               0
# cv__Registration_Date__c     2/18/2010 0:00
# Withdrew                                  0
# Active                                    1
# Registration_Days_Out                  -131
# Opportunity_Amount                      NaN
# AF_PROMO__c                             NaN
# AF_REG_WAY_OF_ENTRY__c             Web Site
# AF_REG_SOURCE__c                      Email
# AF_REG_SOURCE_DETAIL__c                 NaN
# AF_LEAD_GENERATED_DATE__c               NaN
# AF_LEAD_SOURCE__c                     Email
# AF_LEAD_SUBSOURCE__c                    NaN
# Age_During_Event__c                      38
# cv__Team__r.Name                        NaN
# ...

# %%
avon['Year'].value_counts()
# Out:
# 2012    25901
# 2011    25385
# 2013    23102
# 2015    22610
# 2010    21194
# 2016    20767
# 2014    20512
# 2017     5587
# 2009        1
# Name: Year, dtype: int64

# %%
filter_data=avon[avon['Year']!= 2009]

# %%
filter_data['Year'].value_counts()
# Out:
# 2012    25901
# 2011    25385
# 2013    23102
# 2015    22610
# 2010    21194
# 2016    20767
# 2014    20512
# 2017     5587
# Name: Year, dtype: int64

# %%
filter_data=filter_data[avon['Year']!= 2017]
# Out:
# /Applications/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
filter_data['Year'].value_counts()
# Out:
# 2012    25901
# 2011    25385
# 2013    23102
# 2015    22610
# 2010    21194
# 2016    20767
# 2014    20512
# Name: Year, dtype: int64

# %%
filter_data['Walk_Participation'].value_counts()
# Out:
# Walker            139777
# Crew               19302
# Virtual Walker       392
# Name: Walk_Participation, dtype: int64

# %%
filter_data['Classification'].value_counts()
# Out:
# New Direct        52983
# Alumni            50282
# Converted Lead    36512
# Crew              19302
# Virtual Walker      392
# Name: Classification, dtype: int64

# %%
filter_data['Walk_Status'].value_counts()
# Out:
# Active      140384
# Withdrew     19084
# Pending          3
# Name: Walk_Status, dtype: int64

# %%
filter_data['Withdrew'].value_counts()
# Out:
# 0    140387
# 1     19084
# Name: Withdrew, dtype: int64

# %%
filter_data['Active'].value_counts()
# Out:
# 1    140384
# 0     19087
# Name: Active, dtype: int64

# %%
filter_data['FUL_CHECKED'].value_counts()
# Out:
# 1    107468
# 0     52003
# Name: FUL_CHECKED, dtype: int64

# %%
filter_data['Registration_Days_Out'].value_counts().shape
# Out:
# (555,)

# %%
filter_data['AF_PROMO__c'].value_counts().shape
# Out:
# (157,)

# %%
filter_data['AF_REG_WAY_OF_ENTRY__c'].value_counts()
# Out:
# Web Site                  93835
# On Event                  29062
# Phone/Local Office        26633
# DSG                        4862
# Recruitment Activity       2644
# Mail                       1139
# Training/Prep Activity      550
# Orientation Meeting         353
# Name: AF_REG_WAY_OF_ENTRY__c, dtype: int64

# %%
filter_data['AF_REG_SOURCE__c'].value_counts().shape
# Out:
# (49,)

# %%
pd.DataFrame(filter_data['cv__Team__r.Name'].value_counts()).shape
# Out:
# (11499, 1)

# %%
filter_data

# %%
small_data=filter_data[['Year', 'City', 'Classification', 'Walk_Status',
                        'FUL_CHECKED','Registration_Days_Out','AF_PROMO__c',
                       'AF_REG_WAY_OF_ENTRY__c','AF_REG_SOURCE__c','cv__Team__r.Name',
                       'Total_Raised_Master']]

# %%
small_data.describe()
# Out:
#                 Year    FUL_CHECKED  Registration_Days_Out  \
# count  159471.000000  159471.000000          159471.000000
# mean     2012.923372       0.673903             186.173336
# std         1.963972       0.468785             109.621274
# min      2010.000000       0.000000           -1056.000000
# 25%      2011.000000       0.000000              97.000000
# 50%      2013.000000       1.000000             163.000000
# 75%      2015.000000       1.000000             260.000000
# max      2016.000000       1.000000             557.000000
#
#        Total_Raised_Master
# count        159471.000000
# mean           1535.144861
# std            2235.462128
# min               0.000000
# 25%              25.000000
# 50%            1800.000000
# 75%            2167.450000
# max          385074.470000

# %%
small_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 159471 entries, 1 to 159471
# Data columns (total 11 columns):
# Year                      159471 non-null int64
# City                      159471 non-null object
# Classification            159471 non-null object
# Walk_Status               159471 non-null object
# FUL_CHECKED               159471 non-null int64
# Registration_Days_Out     159471 non-null int64
# AF_PROMO__c               80446 non-null object
# AF_REG_WAY_OF_ENTRY__c    159078 non-null object
# AF_REG_SOURCE__c          158354 non-null object
# cv__Team__r.Name          70067 non-null object
# Total_Raised_Master       159471 non-null float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 19.6+ MB

# %%
small_data=small_data.fillna(0)

# %%
small_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 159471 entries, 1 to 159471
# Data columns (total 11 columns):
# Year                      159471 non-null int64
# City                      159471 non-null object
# Classification            159471 non-null object
# Walk_Status               159471 non-null object
# FUL_CHECKED               159471 non-null int64
# Registration_Days_Out     159471 non-null int64
# AF_PROMO__c               159471 non-null object
# AF_REG_WAY_OF_ENTRY__c    159471 non-null object
# AF_REG_SOURCE__c          159471 non-null object
# cv__Team__r.Name          159471 non-null object
# Total_Raised_Master       159471 non-null float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 19.6+ MB

# %%
test_dummy=pd.get_dummies(data=test_dummy, columns=['City', 'Year', 'Classification', 'Walk_Status'])

# %%
test_dummy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 159471 entries, 1 to 159471
# Data columns (total 31 columns):
# FUL_CHECKED                      159471 non-null int64
# Registration_Days_Out            159471 non-null int64
# AF_PROMO__c                      159471 non-null object
# AF_REG_WAY_OF_ENTRY__c           159471 non-null object
# AF_REG_SOURCE__c                 159471 non-null object
# cv__Team__r.Name                 159471 non-null object
# Total_Raised_Master              159471 non-null float64
# City_Boston                      159471 non-null uint8
# City_Charlotte                   159471 non-null uint8
# City_Chicago                     159471 non-null uint8
# City_Houston                     159471 non-null uint8
# City_New York                    159471 non-null uint8
# City_Rocky Mountains             159471 non-null uint8
# City_San Francisco               159471 non-null uint8
# City_Santa Barbara               159471 non-null uint8
# ...

# %%
sns.pairplot(test_dummy)

# %%
#applies dummy variables to whole dataframe
dummied_small_data=pd.get_dummies(small_data)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.pairplot(small_data)

# %%
X=small_data[['Year', 'City', 'Classification', 'Walk_Status',
              'FUL_CHECKED','Registration_Days_Out','AF_PROMO__c',
              'AF_REG_WAY_OF_ENTRY__c','AF_REG_SOURCE__c','cv__Team__r.Name']]

y=small_data['Total_Raised_Master']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((111629, 10), (47842, 10))

# %%
X_train.columns
# Out:
# Index([u'Year', u'City', u'Classification', u'Walk_Status', u'FUL_CHECKED',
#        u'Registration_Days_Out', u'AF_PROMO__c', u'AF_REG_WAY_OF_ENTRY__c',
#        u'AF_REG_SOURCE__c', u'cv__Team__r.Name'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression

# %%
test_column=['City_Boston']

# %%
lr_model1 = LinearRegression()
lr_model1.fit(X_train[test_column],y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-154-6bb2b09d9c87> in <module>()
#       1 lr_model1 = LinearRegression()
# ----> 2 lr_model1.fit(X_train[test_column],y_train)
#
# /Applications/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2054         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2055             # either boolean or fancy integer index
# -> 2056             return self._getitem_array(key)
#    2057         elif isinstance(key, DataFrame):
#    2058             return self._getitem_frame(key)
#
# /Applications/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    2098             return self.take(indexer, axis=0, convert=False)
#    2099         else:
# -> 2100             indexer = self.loc._convert_to_indexer(key, axis=1)
# ...

# %%
## (single) variable coefficient and the intercept
lr_model1.coef_, lr_model1.intercept_
# Out:
# (array([-0.59330303]), 1649.8859711175223)

# %%
plt.figure(figsize=(10,4))
plt.scatter(X_train['Registration_Days_Out'],y_train,alpha=.1)
vec1 = np.linspace(0,700,100)
plt.plot(vec1, lr_model1.intercept_ + lr_model1.coef_[0]*vec1,'r')
plt.xlabel("Registration_Days_Out")
plt.ylabel("Total Raised");
